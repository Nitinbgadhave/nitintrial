-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [SILSERVICE]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 23-03-2024 16:25:11 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CDTransactions]

-- %%
/****** Object:  Table [dbo].[CDTransactions]    Script Date: 23-03-2024 16:25:12 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CDTransactions](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[EmployeeID] [int] NOT NULL,
	[EmployeeName] [nvarchar](max) NOT NULL,
	[Date] [datetime2](7) NOT NULL,
	[Notes] [nvarchar](max) NOT NULL,
	[CreditTransaction] [decimal](18, 2) NOT NULL,
	[DebitTransaction] [decimal](18, 2) NOT NULL,
	[CustomerName] [nvarchar](max) NULL,
	[VisitType] [nvarchar](max) NULL,
	[TransportType] [nvarchar](max) NULL,
	[AllowanceType] [nvarchar](max) NULL,
	[TokenNumber] [nvarchar](max) NULL,
 CONSTRAINT [PK_CDTransactions] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Test_CDTransactions]

-- %%
/****** Object:  Table [dbo].[Test_CDTransactions]    Script Date: 23-03-2024 16:25:12 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Test_CDTransactions](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[EmployeeID] [int] NOT NULL,
	[EmployeeName] [nvarchar](max) NOT NULL,
	[Date] [datetime2](7) NOT NULL,
	[Notes] [nvarchar](max) NOT NULL,
	[CreditTransaction] [decimal](18, 2) NOT NULL,
	[DebitTransaction] [decimal](18, 2) NOT NULL,
	[CustomerName] [nvarchar](max) NULL,
	[VisitType] [nvarchar](max) NULL,
	[TransportType] [nvarchar](max) NULL,
	[AllowanceType] [nvarchar](max) NULL,
	[TokenNumber] [nvarchar](max) NULL,
 CONSTRAINT [PK_Test_CDTransactions] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO
